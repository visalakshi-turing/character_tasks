# %% [markdown]
# # Metadata
#
# **Python Topics** - unit_testing_methodology > best_practices_in_writing_test_cases
#
# **Type** - query
#
# **Target Number of Turns (User + Assistant)** - 1

# %% [markdown]
# # Conversation

# %% [markdown]
# **User**
#
# What is the best practice for naming test functions in Python?
