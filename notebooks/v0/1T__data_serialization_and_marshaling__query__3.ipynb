# %% [markdown]
# # Metadata
#
# **Python Topics** - python_language_and_scripting > data_serialization_and_marshaling
#
# **Type** - query
#
# **Target Number of Turns (User + Assistant)** - 1

# %% [markdown]
# # Conversation

# %% [markdown]
# **User**
#
# Could you provide an example of marshaling a Python dictionary into a byte stream?
