# %%
import sys 
sys.path.append('../../')

service_account_file = 'creds/google__sa.json'

tracking_sheet_id = "1qBU7Kvuuij2fxbqPxebReKMxWgIBmOIE5Gi4ZuX0j_4"
included_sheet_names = [
    "Conversations_Batch_2",
    "Conversations_Batch_3",
    "Conversations_Batch_4",
    "Conversations_Batch_5",
]

jupyter_gdrive_folder_ids = [
    "1Z1bdYMe2Qmo_vs-OaKDaYIiV3rIqLJH9", # V0
    "1sfPFHkXYpKyY41V0pfz3Qw3k4VLy5Hvb", # V1
    "1jV7WA5zB172DJUp7Z2XzHr62E6U6_NtY",
]

delivery_sheet_id = "1eUif5I8xhHU8fY0X9v8r2JI9hWPh7Dq_9VXpSIHwww4"
delivery_jsonl_gdrive_folder_id = "1b3UuMfgwxpOsW0GnsdsrEBWdjUvg8Ub7"

gpt_reviews_path = "gpt_reviews.csv"

# %%
#########################
    # Colab #
#########################

from concurrent.futures import ThreadPoolExecutor, as_completed
from google.oauth2.service_account import Credentials
from googleapiclient.discovery import build
from tqdm import tqdm
import pandas as pd

def get_file_name_from_colab_link(colab_link, service_account_file):
    try:
        file_id = colab_link.split('/drive/')[1]
    except IndexError:
        return None

    SCOPES = ['https://www.googleapis.com/auth/drive']
    credentials = Credentials.from_service_account_file(service_account_file, scopes=SCOPES)
    service = build('drive', 'v3', credentials=credentials)

    try:
        file = service.files().get(fileId=file_id).execute()
        return file.get('name')
    except Exception as e:
        return None


def fetch_file_names_parallel(links, service_account_file, max_workers=100):
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = {executor.submit(get_file_name_from_colab_link, link, service_account_file): link for link in links}
        results = {}
        for future in tqdm(as_completed(futures), total=len(futures), desc="Fetching File Names"):
            link = futures[future]
            try:
                file_name = future.result()
                results[link] = file_name
            except Exception as e:
                results[link] = None
        return results

# %%
from src.sheets_utils import download_sheet_as_df

progress_batches = []
for sheet_name in included_sheet_names:
    print(sheet_name)
    bdf = download_sheet_as_df(service_account_file, tracking_sheet_id, sheet_name)
    progress_batches.append(bdf)
    print(bdf.shape)


delivered = pd.concat([
    download_sheet_as_df(service_account_file, delivery_sheet_id, "Batch 1"),
    download_sheet_as_df(service_account_file, delivery_sheet_id, "Batch 2"),
    download_sheet_as_df(service_account_file, delivery_sheet_id, "Batch 3"),
], ignore_index=True)


df = pd.concat(progress_batches, ignore_index=True)
file_names = fetch_file_names_parallel(df['task_link'], service_account_file)
df['task_file_name'] = df['task_link'].map(file_names)
completed_df = df[df["completion_status"] == "Done"]
completed_to_be_delivered_df = completed_df[~completed_df["task_link"].isin(delivered["task_link"])]

gpt_reviews_df = pd.read_csv(gpt_reviews_path)

completed_to_be_delivered_df = completed_to_be_delivered_df.merge(gpt_reviews_df, on="task_link")
flagged_gpt_reviewer_df = completed_to_be_delivered_df[completed_to_be_delivered_df["avg_jdg_score"] <= 2.5] 
completed_to_be_delivered_df = completed_to_be_delivered_df[completed_to_be_delivered_df["avg_jdg_score"] > 2.5]
flagged_gpt_reviewer_df
# Out:
#                                              task_link  \
# 1    https://colab.research.google.com/drive/1cP6qz...
# 9    https://colab.research.google.com/drive/1d613I...
# 16   https://colab.research.google.com/drive/1xw5RA...
# 17   https://colab.research.google.com/drive/1IMCwR...
# 41   https://colab.research.google.com/drive/1cQ2Az...
# ..                                                 ...
# 531  https://colab.research.google.com/drive/1VJt0i...
# 540  https://colab.research.google.com/drive/1W9TYM...
# 544  https://colab.research.google.com/drive/1wMtlD...
# 551  https://colab.research.google.com/drive/1xF1OD...
# 575  https://colab.research.google.com/drive/1JHlDy...
#
#                                        metadata__topic     assigned_to_email  \
# 1     unit_testing_methodology > test_ai_and_ml_models  patelia.a@turing.com
# 9               algorithms > by_data_structure > trees   ritesh.r@turing.com
# 16          database > indexing_and_search_performance   kumbar.r@turing.com
# 17        algorithms > by_data_structure > hash_tables   ritesh.r@turing.com
# 41                      deep_learning > loss_functions   gedeon.a@turing.com
# ..                                                 ...                   ...
# 531                algorithms > by_topic > game_theory  freitas.g@turing.com
# 540  python_language_and_scripting > basic_python_s...   marcel.s@turing.com
# 544                  algorithms > by_topic > searching     aman.s@turing.com
# 551  python_language_and_scripting > basic_python_s...   marcel.s@turing.com
# 575  Advanced_Debugging_and_Troubleshooting_Debug_e...   marcus.a@turing.com
#
#     completion_status modified_question? duration_mins completion_date  \
# 1                Done              FALSE
# 9                Done                NaN            35      12/28/2023
# 16               Done                NaN            60      12/29/2023
# 17               Done                NaN            25      12/28/2023
# 41               Done                NaN            63        1/1/2024
# ..                ...                ...           ...             ...
# 531              Done                NaN            45        1/2/2024
# 540              Done                NaN            30        1/2/2024
# 544              Done                NaN            42        1/4/2024
# 551              Done                NaN            30        1/2/2024
# 575              Done                NaN            90        1/3/2024
#
#     comments metadata__problem_type metadata__target_length  ...  \
# 1                      modification                       1  ...
# 9                               NaN                      2+  ...
# 16                              NaN                      2+  ...
# 17                              NaN                      2+  ...
# 41                              NaN                      2+  ...
# ..       ...                    ...                     ...  ...
# 531                             NaN                    None  ...
# 540     None                    NaN                    None  ...
# 544     None                    NaN                    None  ...
# 551     None                    NaN                    None  ...
# 575     None                    NaN                    None  ...
#
#            reviewer_email Team_Type(Internal/External)  \
# 1                                             External
# 9    ruturaj.m@turing.com                          NaN
# 16                   None                          NaN
# 17                   None                          NaN
# 41                   None                          NaN
# ..                    ...                          ...
# 531                  None                          NaN
# 540                  None                          NaN
# 544                  None                          NaN
# 551                  None                          NaN
# 575                  None                          NaN
#
#                           metadata__type modified_question  \
# 1                                    NaN               NaN
# 9                                  query             FALSE
# 16                                 query             FALSE
# 17                                 query             FALSE
# 41                                 query             FALSE
# ..                                   ...               ...
# 531  algorithms > by_topic > game_theory             FALSE
# 540                                 None             FALSE
# 544                                 None             FALSE
# 551                                 None             FALSE
# 575                                 None             FALSE
#
#                                         task_file_name  \
# 1     1T__test_ai_and_ml_models__modification__0.ipynb
# 9                                trees__query__1.ipynb
# 16     indexing_and_search_performance__query__2.ipynb
# 17                         hash_tables__query__0.ipynb
# 41                      loss_functions__query__0.ipynb
# ..                                                 ...
# 531            game_theory__modification__2_V3_A.ipynb
# 540    basic_python_syntax__modification__2_V3_A.ipynb
# 544                     searching__query__1_V3_A.ipynb
# 551           basic_python_syntax__query__1_V3_A.ipynb
# 575  Advanced_Debugging_and_Troubleshooting_Debug_e...
#
#                                          code_feedback  \
# 1    #Turn 1:\n\n## Code(2/5):\n**Critical_Issues**...
# 9    #Turn 1:\n\n## Code(4/5):\n**Medium_Issues**\n...
# 16   #Turn 1:\n\n## Code(1/5):\n**Critical_Issues**...
# 17   #Turn 1:\n\n## Code(4/5):\nNone\n\n======\n\n#...
# 41   #Turn 1:\n\n## Code(2/5):\n**Critical_Issues**...
# ..                                                 ...
# 531  #Turn 1:\n\n## Code(2/5):\n**Critical_Issues**...
# 540  #Turn 1:\n\n## Code(4/5):\nNone\n\n======\n\n#...
# 544  #Turn 1:\n\n## Code(2/5):\n**Critical_Issues**...
# 551                    #Turn 1:\n\n## Code(4/5):\nNone
# 575  #Turn 1:\n\n## Code(2/5):\n**Critical_Issues**...
#
#                                          lang_feedback  \
# 1                  #Turn 1:\n\n## Language(4/5):\nNone
# 9    #Turn 1:\n\n## Language(4/5):\n**Medium_Issues...
# 16   #Turn 1:\n\n## Language(3/5):\n**Medium_Issues...
# 17   #Turn 1:\n\n## Language(4/5):\nNone\n\n======\...
# 41   #Turn 1:\n\n## Language(1/5):\n**Medium_Issues...
# ..                                                 ...
# 531  #Turn 1:\n\n## Language(3/5):\n**Medium_Issues...
# 540  #Turn 1:\n\n## Language(4/5):\nNone\n\n======\...
# 544  #Turn 1:\n\n## Language(4/5):\nNone\n\n======\...
# 551                #Turn 1:\n\n## Language(4/5):\nNone
# 575  #Turn 1:\n\n## Language(4/5):\nNone\n\n======\...
#
#                                          code_judgment  \
# 1    The function's name and behavior are mismatche...
# 9    Turn 1 contains a redundant check for None, wh...
# 16   The code provided in each turn either lacks ac...
# 17   The code contains a variable name inconsistenc...
# 41   The code reviews indicate a range of issues fr...
# ..                                                 ...
# 531  The code in each turn has correctness issues o...
# 540  The code in Turn 2 contains a critical error i...
# 544  The code in Turn 1 is incorrect as it misappli...
# 551  The code is correct but may benefit from minor...
# 575  The code in both turns has critical issues rel...
#
#                                          lang_judgment avg_jdg_score
# 1    The assistant's reply is not provided for revi...           1.5
# 9    The assistant's explanations contain redundanc...           2.5
# 16   The responses are generally clear but lack det...           2.5
# 17   The assistant's response contained a major mis...           2.5
# 41   The response is incomplete as it fails to prov...           1.5
# ..                                                 ...           ...
# 531  The responses are understandable but require c...           2.5
# 540  The explanation provided by the assistant cont...           2.5
# 544  The responses are clear but include a signific...           2.5
# 551  The assistant's reply is not available for rev...           2.5
# 575  The response is understandable but contains se...           2.5
#
# [74 rows x 21 columns]

# %%
flagged_gpt_reviewer_df.groupby("assigned_to_email").agg({"completion_status": "count", "avg_jdg_score": "mean"}).sort_values("completion_status", ascending=False)
# Out:
#                         completion_status  avg_jdg_score
# assigned_to_email
# souza.m@turing.com                      8       2.000000
# aman.s@turing.com                       7       2.428571
# adil.m@turing.com                       4       2.375000
# shaharyar.t@turing.com                  4       2.125000
# paulo.c@turing.com                      4       2.500000
# elsadek.a@turing.com                    3       2.500000
# abdul.r@turing.com                      3       2.500000
# ritesh.r@turing.com                     3       2.500000
# marcel.s@turing.com                     3       2.500000
# santiago.c@turing.com                   3       2.500000
# gautam.g@turing.com                     2       1.750000
# khalid.s@turing.com                     2       2.250000
# aarunik.g@turing.com                    2       2.500000
# pawan.s@turing.com                      2       2.000000
# freitas.g@turing.com                    2       2.500000
# edwin.n@turing.com                      2       2.500000
# caram.v@turing.com                      2       2.500000
# armas.j@turing.com                      2       2.500000
# andranik.g@turing.com                   2       2.500000
# ali.nauman@turing.com                   2       2.000000
# toh.y@turing.com                        2       2.500000
#                                         1       2.500000
# ishwar.b@turing.com                     1       2.500000
# patelia.a@turing.com                    1       1.500000
# martinho.h@turing.com                   1       2.000000
# marcus.a@turing.com                     1       2.500000
# kumbar.r@turing.com                     1       2.500000
# jha.r@turing.com                        1       2.000000
# gedeon.a@turing.com                     1       1.500000
# abdullah.i@turing.com                   1       2.500000
# zubair.m@turing.com                     1       2.500000

# %%
from src.sheets_utils import upload_df_to_sheet

flagged_gpt_reviewer_df = flagged_gpt_reviewer_df.fillna("")
upload_df_to_sheet(service_account_file, tracking_sheet_id, "gpt_flags_1", flagged_gpt_reviewer_df)
